# %%
import numpy as np

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a26e83b1-4d4b-4f55-a85a-70fd3415a5ac" name="files[]" multiple disabled />
#      <output id="result-a26e83b1-4d4b-4f55-a85a-70fd3415a5ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving u.data to u.data

# %%
column_names = ['user_id','item_id','rating','timestamp']

# %% [markdown]
# # #Recommendation Systems based on Collaborative Filtering

# %%
df = pd.read_csv('u.data',sep='\t',names=column_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-141991bb-6945-4519-ae3d-61a5b4f8774f" name="files[]" multiple disabled />
#      <output id="result-141991bb-6945-4519-ae3d-61a5b4f8774f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Movie_Id_Titles to Movie_Id_Titles

# %%
movie_titles = pd.read_csv('Movie_Id_Titles')

# %%
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df = pd.merge(df,movie_titles,on='item_id')

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('white')
# %matplotlib inline

# %%
df.groupby('title')['rating'].mean().head()
# Out:
# title
# 'Til There Was You (1997)    2.333333
# 1-900 (1994)                 2.600000
# 101 Dalmatians (1996)        2.908257
# 12 Angry Men (1957)          4.344000
# 187 (1997)                   3.024390
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['Num Of Ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())

# %%
ratings.head()
# Out:
#                              rating  Num Of Ratings
# title
# 'Til There Was You (1997)  2.333333               9
# 1-900 (1994)               2.600000               5
# 101 Dalmatians (1996)      2.908257             109
# 12 Angry Men (1957)        4.344000             125
# 187 (1997)                 3.024390              41

# %%
# OK, let's build some Visualizations!

ratings['Num Of Ratings'].hist(bins=30)

# %%
ratings['rating'].hist(bins=65)

# %%
sns.jointplot(x='rating',y='Num Of Ratings',data = ratings, alpha = 0.5)

# %% [markdown]
# # Recommendation Systems based on Content-based Filtering

# %%
moviematrix = df.pivot_table(index='user_id',columns='title',values='rating') #since we are concerned with user_id,rating,and the movie_title, we create a pivot_table using these values.

# %%
moviematrix.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
ratings.sort_values('Num Of Ratings',ascending=False).head(10)
# Out:
#                                  rating  Num Of Ratings
# title
# Star Wars (1977)               4.359589             584
# Contact (1997)                 3.803536             509
# Fargo (1996)                   4.155512             508
# Return of the Jedi (1983)      4.007890             507
# Liar Liar (1997)               3.156701             485
# English Patient, The (1996)    3.656965             481
# Scream (1996)                  3.441423             478
# Toy Story (1995)               3.878319             452
# Air Force One (1997)           3.631090             431
# Independence Day (ID4) (1996)  3.438228             429

# %%
starwars_user_ratings = moviematrix['Star Wars (1977)']
liarliar_user_ratings = moviematrix['Liar Liar (1997)']

# %%
starwars_user_ratings.head()
# Out:
# user_id
# 0    5.0
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# Name: Star Wars (1977), dtype: float64

# %%
same_as_starwars = moviematrix.corrwith(starwars_user_ratings)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:3175: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)

# %%
same_as_starwars
# Out:
# title
# 'Til There Was You (1997)                                   0.872872
# 1-900 (1994)                                               -0.645497
# 101 Dalmatians (1996)                                       0.211132
# 12 Angry Men (1957)                                         0.184289
# 187 (1997)                                                  0.027398
# 2 Days in the Valley (1996)                                 0.066654
# 20,000 Leagues Under the Sea (1954)                         0.289768
# 2001: A Space Odyssey (1968)                                0.230884
# 3 Ninjas: High Noon At Mega Mountain (1998)                      NaN
# 39 Steps, The (1935)                                        0.106453
# 8 1/2 (1963)                                               -0.142977
# 8 Heads in a Duffel Bag (1997)                             -0.577350
# 8 Seconds (1994)                                           -0.755929
# ...

# %%
same_as_liarliar = moviematrix.corrwith(liarliar_user_ratings)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:3175: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)

# %%
same_as_liarliar
# Out:
# title
# 'Til There Was You (1997)                                   0.118913
# 1-900 (1994)                                                     NaN
# 101 Dalmatians (1996)                                       0.469765
# 12 Angry Men (1957)                                         0.066272
# 187 (1997)                                                  0.175145
# 2 Days in the Valley (1996)                                 0.040739
# 20,000 Leagues Under the Sea (1954)                        -0.027932
# 2001: A Space Odyssey (1968)                               -0.057864
# 3 Ninjas: High Noon At Mega Mountain (1998)                      NaN
# 39 Steps, The (1935)                                        0.400918
# 8 1/2 (1963)                                                0.178064
# 8 Heads in a Duffel Bag (1997)                                   NaN
# 8 Seconds (1994)                                                 NaN
# ...

# %%
corr_starwars = pd.DataFrame(same_as_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)

# %%
corr_starwars.head()
# Out:
#                            Correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %%
corr_liarliar = pd.DataFrame(same_as_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)

# %%
corr_liarliar.head()
# Out:
#                              Correlation
# title
# 'Til There Was You (1997)       0.118913
# 101 Dalmatians (1996)           0.469765
# 12 Angry Men (1957)             0.066272
# 187 (1997)                      0.175145
# 2 Days in the Valley (1996)     0.040739

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                     Correlation
# title
# Hollow Reed (1996)                                          1.0
# Commandments (1997)                                         1.0
# Cosi (1996)                                                 1.0
# No Escape (1994)                                            1.0
# Stripes (1981)                                              1.0
# Star Wars (1977)                                            1.0
# Man of the Year (1995)                                      1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0

# %%
# This arrangement here may or may not indicate actual relationship between the movies. To eradicate that option, we use a sort of filtering technique as given below:

# %%
corr_starwars = corr_starwars.join(ratings['Num Of Ratings'])

# %%
corr_starwars.head()
# Out:
#                            Correlation  Num Of Ratings
# title
# 'Til There Was You (1997)     0.872872               9
# 1-900 (1994)                 -0.645497               5
# 101 Dalmatians (1996)         0.211132             109
# 12 Angry Men (1957)           0.184289             125
# 187 (1997)                    0.027398              41

# %%
corr_starwars[corr_starwars['Num Of Ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                                     Correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.748353
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
#
#                                                     Num Of Ratings
# title
# Star Wars (1977)                                               584
# Empire Strikes Back, The (1980)                                368
# Return of the Jedi (1983)                                      507
# Raiders of the Lost Ark (1981)                                 420
# Austin Powers: International Man of Mystery (1997)             130

# %%
corr_liarliar.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                          Correlation
# title
# Bonheur, Le (1965)                               1.0
# For Ever Mozart (1996)                           1.0
# Crossfire (1947)                                 1.0
# Johnny 100 Pesos (1993)                          1.0
# Moonlight and Valentino (1995)                   1.0
# Mina Tannenbaum (1994)                           1.0
# Stranger, The (1994)                             1.0
# Wooden Man's Bride, The (Wu Kui) (1994)          1.0
# Legal Deceit (1997)                              1.0
# Liar Liar (1997)                                 1.0

# %%
corr_liarliar = corr_liarliar.join(ratings['Num Of Ratings'])

# %%
corr_liarliar.head()
# Out:
#                              Correlation  Num Of Ratings
# title
# 'Til There Was You (1997)       0.118913               9
# 101 Dalmatians (1996)           0.469765             109
# 12 Angry Men (1957)             0.066272             125
# 187 (1997)                      0.175145              41
# 2 Days in the Valley (1996)     0.040739              93

# %%
corr_liarliar[corr_liarliar['Num Of Ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                        Correlation  Num Of Ratings
# title
# Liar Liar (1997)          1.000000             485
# Batman Forever (1995)     0.516968             114
# Mask, The (1994)          0.484650             129
# Down Periscope (1996)     0.472681             101
# Con Air (1997)            0.469828             137
